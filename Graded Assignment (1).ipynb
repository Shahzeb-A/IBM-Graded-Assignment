# %% [markdown]
# # MyJupyter Notebook on IBM Watson Studio

# %% [markdown]
#   **Shahzeb Ali**
# Data Scientist

# %% [markdown]
# *I am interested in data science because of Math's and Statistics plus I love to work with AI models and love how satifiying it's to play with data*

# %% [markdown]
# ### It's used to display hello world in a program

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# * Python
# * R
# * IBM Watson Studio
#
# 1. Python
# 2. R
# 3. IBM Watson Studio
#
# > Python
#
# > R
#
# > IBM Watson Studio
